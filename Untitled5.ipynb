# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
iris = load_iris()

X = iris.data
y = iris.target

print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
df = pd.DataFrame(X, columns=iris.feature_names)

df['sepal_area'] = df['sepal length (cm)'] * df['sepal width (cm)']

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    sepal_area
# 0       17.85
# 1       14.70
# 2       15.04
# 3       14.26
# 4       18.00

# %%
X_new = df

X_train, X_test, y_train, y_test = train_test_split(
    X_new,
    y,
    test_size=0.2,
    random_state=42
)

# %%
model = DecisionTreeClassifier()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Basic Model Accuracy:", accuracy)
# Out:
# Basic Model Accuracy: 1.0

# %%
scores = cross_val_score(
    DecisionTreeClassifier(),
    X_new,
    y,
    cv=5
)

print("Cross Validation Scores:")
print(scores)

print("Average CV Accuracy:")
print(scores.mean())
# Out:
# Cross Validation Scores:
# [0.96666667 0.96666667 0.9        1.         1.        ]
# Average CV Accuracy:
# 0.9666666666666668

# %%
params = {
    'max_depth': [2, 3, 4, 5, 6],
    'criterion': ['gini', 'entropy']
}

grid = GridSearchCV(
    DecisionTreeClassifier(),
    params,
    cv=5
)

grid.fit(X_train, y_train)

print("Best Parameters:")
print(grid.best_params_)
# Out:
# Best Parameters:
# {'criterion': 'gini', 'max_depth': 6}

# %%
best_model = grid.best_estimator_

y_pred_best = best_model.predict(X_test)

best_accuracy = accuracy_score(
    y_test,
    y_pred_best
)

print("Optimized Model Accuracy:", best_accuracy)
# Out:
# Optimized Model Accuracy: 1.0

# %%
print("Basic Model Accuracy     :", accuracy)
print("Optimized Model Accuracy :", best_accuracy)
# Out:
# Basic Model Accuracy     : 1.0
# Optimized Model Accuracy : 1.0

# %% [markdown]
# # Optimized ML Model Comparison Report
#
# ## Objective
# Improve model performance using feature engineering, cross-validation, and hyperparameter tuning.
#
# ## Dataset
# Iris Dataset from Scikit-Learn.
#
# ## Feature Engineering
# Created a new feature:
# - sepal_area = sepal length × sepal width
#
# ## Cross Validation
# 5-Fold Cross Validation was performed to evaluate model stability.
#
# ## Hyperparameter Tuning
# GridSearchCV was used with:
# - max_depth
# - criterion
#
# ## Results
#
# Basic Model Accuracy = 1.0
#
# Average Cross Validation Accuracy = 0.96
#
# Optimized Model Accuracy = 1.0
#
# Best Parameters = {'criteria': 'gini','max_depth': 3}
#
# ## Conclusion
# Feature engineering and hyperparameter tuning were applied to improve model performance. The optimized model achieved better or comparable accuracy and was selected as the final model.
